# %% [markdown]
# # **Projeto de Machine Learning**

# %% [markdown]
# ---

# %% [markdown]
# Objetivo: **Desenvolver um pipeline completo de Machine Learning usando o dataset** [Adult Census Income](https://archive.ics.uci.edu/ml/datasets/Adult) da [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).
#
# Grupo: `dupla` - `até 2 pessoas`

# %% [markdown]
# ---

# %% [markdown]
# O projeto de Machine Learning está dividido em 3 etapas, sendo elas:
#
# - APS1: **Projeto EDA** (20%)
# - APS2: **Projeto Regressão** (40%)
# - APS3: **Projeto Classificação** (40%)
#
# Lembrando das regras:
#
# - APS entregue fora do prazo, conceito limite é C;
# - APS não entregue implica em conceito I;
# - **Com conceito I em qualquer APS, toda a nota de grupo é ZERO**, ou seja, não entregar qualquer uma das APSs implica em zerar a nota de grupo.

# %% [markdown]
# ## Entrega

# %% [markdown]
# - Cada etapa do projeto tem seu `deadline`;
# - A entrega deve ser feita via BlackBoard, com um arquivo `.ipynb` ou com um link para um `Colab`;
# - O material entregue deve ter, além dos requisitados básicos de cada etapa:
#     - Identificação dos membros do grupo;
#     - Título do projeto;
#     - Data de entrega;
#     - Referências bibliográficas utilizadas (se houver);
#     - Qualquer outra informação que o grupo julgar relevante para a avaliação do projeto.

# %% [markdown]
# ## **Dataset**

# %% [markdown]
# O dataset no qual o projeto deve ser desenvolvido é o [Adult Census Income](https://archive.ics.uci.edu/ml/datasets/Adult) da [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/). Ele contém informações sobre indivíduos, como idade, trabalho, educação, estado civil, ocupação, renda, entre outros.

# %% [markdown]
# ## APS1: **EDA**

# %% [markdown]
# > Deadline: 12 Março, 2026

# %% [markdown]
# Na etapa de EDA, o grupo deve realizar uma análise exploratória abrangente para entender a estrutura, qualidade, distribuições, relações entre variáveis (numéricas e categóricas) e desafios, como missing values e vieses, preparando para encoding e modelagem nas fases subsequentes.
# Descrição do Dataset: O dataset Adult consiste em 48.842 instâncias, cada uma representando um indivíduo com 14 features mistas e o target 'income'. Valores ausentes são representados por '?'. Use o conjunto completo para EDA, mas amostras estratificadas (por income) para visualizações eficientes se necessário.
#
# Tarefas básicas de EDA:
#
# 1. Carregamento e inspeção inicial dos dados:
#
#     - Explicar cada feature do dataset;
#     - Verificar o número de instâncias e features.
#     - Identificar tipos de dados (numéricos, categóricos).
#     - Detectar valores ausentes ('?') e inconsistências.
#     - Analisar a distribuição do target 'income'.
#
# 2. Análise univariada:
#
#     - Para variáveis numéricas: calcular estatísticas descritivas (média, mediana, desvio padrão) e criar histogramas ou boxplots.
#     - Para variáveis categóricas: calcular frequências e criar gráficos de barras.
#     - Detectar outliers em variáveis numéricas usando boxplots ou z-scores.
#
# 3. Análise bivariada e multivariada:
#
#     - Analisar correlações entre variáveis numéricas usando matrizes de correlação e scatter plots (use heatmaps para visualização).
#     - Analisar relações entre variáveis categóricas e o target 'income' usando gráficos de barras ou tabelas de contingência.
#     - Analisar relações entre variáveis numéricas e categóricas usando boxplots ou violin plots.
#
# 4. Análise de qualidade dos dados:
#
#     - Identificar e quantificar valores ausentes.
#     - Analisar a distribuição de classes no target 'income' para detectar desequilíbrios.
#     - Identificar possíveis vieses ou inconsistências nos dados.
#
# 5. Pré-processamento para modelagem:
#
#     - Propor estratégias para lidar com valores ausentes (remoção, imputação).
#     - Propor estratégias para lidar com outliers (remoção, transformação).
#     - Propor estratégias para lidar com desequilíbrios de classe (undersampling, oversampling).
#     - Propor estratégias para encoding de variáveis categóricas (one-hot encoding, label encoding).
#     - Propor estratégias para normalização ou padronização de variáveis numéricas (Min-Max Scaling, Standardization, etc.).
#     - Construir um pipeline de pré-processamento que inclua as etapas acima, garantindo que seja aplicável para as fases de modelagem subsequentes.
#
# 6. Redução de dimensionalidade:
#
#     - Propor e aplicar técnicas de redução de dimensionalidade, como PCA, t-SNE ou UMAP, para visualizar a estrutura dos dados e identificar possíveis agrupamentos ou padrões.
#     - Analisar os resultados da redução de dimensionalidade para obter insights sobre a separabilidade das classes e a importância das features.
#
# 7. Documentação e apresentação:
#
#     - Documentar todas as etapas da análise, incluindo insights e decisões tomadas. **Justificar as escolhas de pré-processamento com base nos achados da EDA.**
#     - Sugerir feature engineering baseada nos insights da EDA, como criação de novas features a partir das existentes (ex: idade em grupos, interações entre variáveis).
#     - Criar visualizações claras e informativas para comunicar os resultados da EDA.
#     - Preparar um relatório que resuma os principais achados e as estratégias propostas para a modelagem.
#     - Discutir as limitações do dataset e os desafios que podem surgir durante a modelagem, como overfitting, underfitting, ou problemas de generalização.
#     - Discutir implicações das descobertas através das análises do dataset para:
#
#         - Regressão, e;
#         - Classificação.
#
# Instruções adicionais:
#
# - O código deve ser bem organizado, com comentários explicativos para cada etapa.
# - As visualizações devem ser claras, com títulos, rótulos e legendas adequados
# - O relatório deve ser conciso, focando nos insights mais relevantes e nas decisões de pré-processamento.
# - O grupo deve justificar todas as escolhas de pré-processamento com base nos achados da EDA, garantindo que as estratégias propostas sejam adequadas para os desafios identificados no dataset.
# - O relatório deve incluir uma seção de conclusões, resumindo os principais insights e as estratégias propostas para a modelagem, além de discutir as limitações do dataset e os desafios que podem surgir durante a modelagem.
# - Python obrigatório, utilizando bibliotecas como Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, entre outras para análise e visualização dos dados.

# %% [markdown]
# ### Critérios de avaliação:
#
# | Conceito | Descrição |
# | --- | --- |
# | `I` | Não entrega da APS. |
# | `D` | Entrega com contúdo incompleto, análise superficial, falta de justificativas para as escolhas de pré-processamento, ou visualizações inadequadas. |
# | `C` | Entrega completa, mas com algumas falhas na análise, justificativas ou visualizações. |
# | `B` | Entrega completa, com análise detalhada, justificativas claras para as escolhas de pré-processamento, e visualizações adequadas. |
# | `A` | Entrega completa, com análise aprofundada, justificativas muito claras e bem fundamentadas para as escolhas de pré-processamento, visualizações excelentes, e um relatório muito bem estruturado e informativo. |
#
# O critério `+` pode ser utilizado para destacar entregas que se destacam em algum aspecto específico, como criatividade na análise, qualidade das visualizações ou clareza do relatório.

# %% [markdown]
# ## APS2: **Regressão**

# %% [markdown]
# > Deadline: 21 Maio, 2026

# %% [markdown]
# **Previsão de Horas Trabalhadas por Semana**

# %% [markdown]
# Desenvolver e avaliar modelos de regressão para prever a variável contínua `hours-per-week` (número médio de horas trabalhadas por semana) utilizando as demais características do indivíduo presentes no dataset [Adult Census Income](https://archive.ics.uci.edu/ml/datasets/Adult).
#
# Este projeto tem forte relevância prática: a previsão de carga horária de trabalho é útil em estudos de economia do trabalho, políticas públicas de emprego, RH e análise de desigualdades (ex.: impacto de gênero, raça e nível educacional na jornada de trabalho).

# %% [markdown]
# Elementos do projeto:
#
# 1. Feature Engineering criativo (obrigatório criar ao menos 4 novas features). Exemplos sugeridos:
#
#     - `capital_net` = `capital-gain` − `capital-loss`;
#     - `education_level` (binning ou ordinal de education-num);
#     - `work_experience_proxy` = `age` − `education-num` − $6$;
#     - Interações: `education` × `occupation`, `age` × `marital-status`, `sex` × `hours-per-week` (para análise de viés)
#
# 1. Modelagem:
#
#     - Mínimo 3 modelos distintos, incluindo:
#
#         - Baseline: Linear Regression / Ridge / Lasso;
#         - Ensemble: Random Forest Regressor, XGBoost Regressor;
#
#     - Validação cruzada robusta (Repeated K-Fold $5×$ ou $10×$ com random_state fixo).
#
# 1. Otimização e seleção de modelo:
#
#     - Hyperparameter tuning (GridSearchCV ou Optuna/RandomizedSearchCV);
#     - Comparação estatística entre modelos.
#
# 1. Análises de métricas sobre o modelo.
#
# 1. Interpretação e explicabilidade.
#
# 1. Discussão crítica obrigatória:
#
#     - Limitações do modelo (multimodalidade da target, heterocedasticidade, causalidade vs. correlação);
#     - Sugestões de melhoria e próximos passos.

# %% [markdown]
# Instruções adicionais:
#
# - O código deve ser bem organizado, com comentários explicativos para cada etapa;
# - As visualizações devem ser claras, com títulos, rótulos e legendas adequados;
# - O relatório deve ser conciso, focando nos insights mais relevantes e nas decisões de pré-processamento;
# - O grupo deve justificar todas as escolhas de parâmetros;
# - O relatório deve incluir uma seção de conclusões, resumindo os principais insights e as estratégias propostas para a modelagem, além de discutir as limitações do dataset e os desafios que podem surgir durante o uso do modelo;
# - Python obrigatório, utilizando bibliotecas como Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, entre outras para análise e visualização dos dados.

# %% [markdown]
# ### Critérios de avaliação:
#
# | Conceito | Descrição |
# | --- | --- |
# | `I` | Não entrega do projeto de regressão. |
# | `D` | Entrega com conteúdo incompleto, análise superficial, falta de modelos ou métricas, ausência de justificativas para as escolhas de pré-processamento e feature engineering, ou visualizações e código inadequados. |
# | `C` | Entrega completa, mas com falhas evidentes: uso de poucos modelos, métricas incompletas, justificativas fracas, análise de resíduos superficial, feature engineering básico ou interpretação limitada dos resultados. |
# | `B` | Entrega completa e sólida, com análise detalhada, pelo menos 3 modelos implementados corretamente, uso adequado de validação cruzada, métricas completas (RMSE, MAE, R², etc.), análise de resíduos razoável, feature engineering adequado e boas justificativas para as decisões tomadas. |
# | `A` | Entrega excelente: análise aprofundada e crítica, feature engineering criativo (com pelo menos 3 novas features relevantes), implementação de no mínimo 3 modelos (incluindo ensembles), hyperparameter tuning bem conduzido, análise completa de resíduos, uso de técnicas de interpretabilidade (SHAP, PDP ou permutation importance), um relatório muito bem estruturado, claro e com reflexões críticas sobre as limitações e implicações do modelo. |
#
# **Critério `+` (plus)**:
# Pode ser utilizado para destacar entregas que se sobressaem em algum aspecto específico, como:
# - Criatividade no feature engineering ou na análise de interpretabilidade
# - Qualidade excepcional das visualizações e da análise de resíduos
# - Uso avançado de ferramentas (Optuna, SHAP, fairlearn, etc.)
# - Clareza, organização e profundidade acadêmica do relatório
#
# **Observação importante**:
# Uma entrega nota `A` deve demonstrar que o aluno compreendeu profundamente os desafios de um problema de regressão real: multimodalidade da variável alvo, heterocedasticidade, multicolinearidade e viés em dados demográficos.

# %% [markdown]
# ## APS3: **Classificação**

# %% [markdown]
# > Deadline: 21 Maio, 2026

# %% [markdown]
# **Previsão de Renda Anual**

# %% [markdown]
# Desenvolver e avaliar modelos de classificação binária para prever se um indivíduo ganha mais de $50K$ por ano (`income > 50K`) ou não, com base nas características demográficas, educacionais e ocupacionais presentes no Adult Census Income Dataset.
#
# Esta tarefa possui alta relevância prática em áreas como políticas públicas, recrutamento, análise de desigualdade social e estudos socioeconômicos.

# %% [markdown]
# As features com maior poder discriminativo esperado são: `education-num`, `capital-gain`, `capital-loss`, `hours-per-week`, `age`, `marital-status`, `occupation` e `relationship`. O aluno deve analisar explicitamente quais variáveis melhor separam as duas classes.
#
#
# - Métricas de avaliação obrigatórias (todas devem ser reportadas):
#
#     - Accuracy;
#     - Precision, Recall e F1-score (macro, weighted e por classe);
#     - ROC-AUC (área sob a curva ROC);
#     - PR-AUC (área sob a curva Precision-Recall) – especialmente importante devido ao desbalanceamento;
#     - Confusion Matrix com análise detalhada de falsos positivos e falsos negativos.
#
# Elementos do projeto:
#
# 1. Técnicas de balanceamento: class weights, SMOTE, undersampling ou threshold moving (com justificativa);
#
# 1. Feature Engineering criativo (obrigatório criar ao menos 3 novas features). Exemplos sugeridos:
#
#     - `capital_net` = `capital-gain` - `capital-loss`
#     - `work_experience_proxy` = `age` - `education-num` - $6$;
#     - Interações: `education-num` × `occupation`, `marital-status` × `age`, `sex` × `hours-per-week`
#
#
# 1. Modelagem:
#
#     - Mínimo 3 modelos distintos, incluindo:
#
#         - Baseline: Linear Regression / Ridge / Lasso;
#         - Ensemble: Random Forest Regressor, XGBoost Regressor;
#
#     - Validação cruzada robusta (Repeated K-Fold $5×$ ou $10×$ com random_state fixo).
#
# 1. Otimização e seleção de modelo:
#
#     - Hyperparameter tuning (GridSearchCV ou Optuna/RandomizedSearchCV);
#     - Comparação estatística entre modelos.
#
# 1. Análises de métricas sobre o modelo.
#
# 1. Interpretação e explicabilidade.
#
# 1. Discussão crítica obrigatória:
#
#     - Limitações do modelo (multimodalidade da target, heterocedasticidade, causalidade vs. correlação);
#     - Sugestões de melhoria e próximos passos.

# %% [markdown]
# Instruções adicionais:
#
# - O código deve ser bem organizado, com comentários explicativos para cada etapa;
# - As visualizações devem ser claras, com títulos, rótulos e legendas adequados;
# - O relatório deve ser conciso, focando nos insights mais relevantes e nas decisões de pré-processamento;
# - O grupo deve justificar todas as escolhas de parâmetros;
# - O relatório deve incluir uma seção de conclusões, resumindo os principais insights e as estratégias propostas para a modelagem, além de discutir as limitações do dataset e os desafios que podem surgir durante o uso do modelo;
# - Python obrigatório, utilizando bibliotecas como Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, entre outras para análise e visualização dos dados.

# %% [markdown]
# #### Critérios de avaliação:
#
# | Conceito | Descrição |
# | --- | --- |
# | `I` | Não entrega do projeto de classificação. |
# | `D` | Entrega com conteúdo incompleto, análise superficial de separabilidade, ausência de tratamento de desbalanceamento, falta de modelos ou métricas, ou justificativas inadequadas para as escolhas realizadas. |
# | `C` | Entrega completa, mas com falhas: uso de poucos modelos, métricas incompletas (faltando PR-AUC ou análise por classe), feature engineering básico, tratamento superficial de desbalanceamento ou interpretação limitada. |
# | `B` | Entrega completa e sólida, com análise detalhada de separabilidade, pelo menos 3 modelos implementados corretamente, uso adequado de validação cruzada estratificada, métricas completas (incluindo Precision, Recall, F1, ROC-AUC e PR-AUC), feature engineering adequado, tratamento justificado de desbalanceamento e boas justificativas. |
# | `A` | Entrega excelente: análise aprofundada de separabilidade e desbalanceamento, feature engineering criativo (com pelo menos 3 novas features relevantes), implementação de no mínimo 3 modelos (incluindo ensembles), hyperparameter tuning bem conduzido, uso avançado de interpretabilidade (SHAP values), e um relatório muito bem estruturado e limitações do modelo. |
#
# **Critério `+` (plus)**:
# Pode ser utilizado para destacar entregas que se sobressaem em algum aspecto específico, como:
# - Criatividade no feature engineering ou na análise de fairness
# - Qualidade excepcional das visualizações de separabilidade e SHAP plots
# - Uso avançado de técnicas para dados desbalanceados ou ferramentas de interpretabilidade
# - Clareza, organização e profundidade acadêmica do relatório, com excelente conexão entre análise e decisões de modelagem
